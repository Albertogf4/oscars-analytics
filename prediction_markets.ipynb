# %% [markdown]
# # Objects In Kalshi
#
# ## 1. Market (elemento mínimo -> extraes información básica de precio)
# A single binary market. This is a low level object ehich rarely will need to be exposed on its own to members. ç
#
# ## 2. Event (acontecimiento cultural que da lugar a una serie de mercados)
# An event is a collection of markets and the basic unit that members should interact with.
#
# ## 3. Series (catálogo de eventos relacionados entre sí)
# A series is a collection of related events.
# - Each event should look at similar data for determination, but translated over another, disjoint time period.
# - Series should never have logical outcom dependency between events
# - Events in a series should have the same ticker prefic

# %%
# Get series information for KXHIGHNY
import requests
url = "https://api.elections.kalshi.com/trade-api/v2/series"
response = requests.get(url)
print(f"Status Code: {response.status_code}")
series_data = response.json()
# filter out and show all of the series that contain the word "Oscar"
print(f"Total Series: {len(series_data['series'])}")
for series in series_data['series']:
    if "Oscar" in series['title']:
        print(f"- {series['ticker']}: {series['title']} (Frequency: {series['frequency']}, Category: {series['category']})")
# Out:
# Status Code: 200
# Total Series: 8379
# - KXOSCARANIMATED: Oscar for Best Animated Feature (Frequency: one_off, Category: Entertainment)
# - KXOSCARSOUND: Oscar for Best Sound (Frequency: one_off, Category: Entertainment)
# - OSCARCOUNTOPPENHEIMER: Oppenheimer Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARSONG: Oscar for Best Original Song (Frequency: one_off, Category: Entertainment)
# - KXOSCARNOMINEESPIC: All Oscar nominations for Best Picture (Frequency: annual, Category: Entertainment)
# - OSCARPIC: Oscar for Best Picture (Frequency: annual, Category: Entertainment)
# - OSCARNOMSUPACTO: Oscar nominations for Best Supporting Actor (Frequency: annual, Category: Entertainment)
# - KXOSCARCOUNTEMILIAPEREZ: Emilia Perez Oscar wins (Frequency: custom, Category: Entertainment)
# - OSCARSPLAY: Oscar for Best Original Screenplay (Frequency: annual, Category: Entertainment)
# - OSCARCOUNTDUNE2: Dune Part Two Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARPROD: Oscar for Best Production Design (Frequency: one_off, Category: Entertainment)
# - KXOSCARACTR: Oscar for Best Actress (Frequency: annual, Category: Entertainment)
# - OSCARNOMACTO: Oscar nominations for Best Actor (Frequency: annual, Category: Entertainment)
# - KXOSCARCOUNTBRUTALIST: BRUTALIST Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARDEI: Oscars DEI ended (Frequency: custom, Category: Entertainment)
# - KXOSCARNOMBCASTING: Oscar nominations for Best Casting (Frequency: annual, Category: Entertainment)
# - KXOSCARCOUNTCONCLAVE: Conclave Oscar wins (Frequency: custom, Category: Entertainment)
# - OSCARDIR: Oscar for Best Director (Frequency: annual, Category: Entertainment)
# - OSCARACTO: Oscar for Best Actor (Frequency: annual, Category: Entertainment)
# - KXOSCARSUPACTR: Oscar for Best Supporting Actress (Frequency: annual, Category: Entertainment)
# - OSCARCOUNTBARBIE: Barbie Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARLAS: Oscar for Best LIVE ACTION SHORT (Frequency: annual, Category: Entertainment)
# - KXOSCARPIC: Oscar for Best Picture (Frequency: annual, Category: Entertainment)
# - KXOSCAREDIT: Oscar for Best FILM EDITING (Frequency: annual, Category: Entertainment)
# - KXOSCARCOUNTDUNE2: Dune Part Two Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARGUESTS: Oscar guests (Frequency: custom, Category: Entertainment)
# - OSCARASPLAY: Oscar for Best Adapted Screenplay (Frequency: annual, Category: Entertainment)
# - KXOSCARCINE: Oscar for Best Cinematography (Frequency: annual, Category: Entertainment)
# - OSCARACTR: Oscar for Best Actress (Frequency: annual, Category: Entertainment)
# - KXOSCARNOMSUPACTO: Oscar nominations for Best Supporting Actor (Frequency: annual, Category: Entertainment)
# - KXOSCARMAH: Oscar for Best MAKEUP AND HAIRSTYLING (Frequency: annual, Category: Entertainment)
# - OSCARPROD: Oscar for Best Production Design (Frequency: one_off, Category: Entertainment)
# - KXOSCARNOMDOCU: Oscar nominations for Best Documentary Feature Film (Frequency: annual, Category: Entertainment)
# - KXOSCARDIR: Oscar for Best Director (Frequency: annual, Category: Entertainment)
# - OSCARANIMATED: Oscar for Best Animated Feature (Frequency: one_off, Category: Entertainment)
# - KXOSCARCOUNTOPPENHEIMER: Oppenheimer Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARACTO: Oscar for Best Actor (Frequency: annual, Category: Entertainment)
# - KXOSCARNOMACTO: Oscar nominations for Best Actor (Frequency: annual, Category: Entertainment)
# - KXOSCARNOMDIR: Oscar nominations for Best Director (Frequency: annual, Category: Entertainment)
# - KXOSCARCOSTUME: Oscar for Best Costume Design (Frequency: one_off, Category: Entertainment)
# - KXOSCARDS: Oscar for Best DOCUMENTARY SHORT (Frequency: annual, Category: Entertainment)
# - KXOSCARCOUNTANORA: Anora Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARSPLAY: Oscar for Best Original Screenplay (Frequency: annual, Category: Entertainment)
# - KXOSCARASPLAY: Oscar for Best Adapted Screenplay (Frequency: annual, Category: Entertainment)
# - KXOSCARSUPACTO: Oscar for Best Supporting Actor (Frequency: annual, Category: Entertainment)
# - OSCARNOMACTR: Oscar nominations for Best ActRESS (Frequency: annual, Category: Entertainment)
# - KXOSCARCOUNTSUBSTANCE: The Substance Oscar Wins (Frequency: custom, Category: Entertainment)
# - KXOSCARNOMACTR: Oscar nominations for Best ActRESS (Frequency: annual, Category: Entertainment)
# - OSCARNOMPIC: Oscar nominations for Best Picture (Frequency: custom, Category: Entertainment)
# - KXOSCARINTLFILM: Oscar for Best International Feature Film (Frequency: annual, Category: Entertainment)
# - OSCARSONG: Oscar for Best Original Song (Frequency: one_off, Category: Entertainment)
# - OSCARSUPACTO: Oscar for Best Supporting Actor (Frequency: annual, Category: Entertainment)
# - OSCARVIS: Oscar for Best Visual Effects (Frequency: annual, Category: Entertainment)
# - KXOSCARMENTION: Oscar mentions (Frequency: custom, Category: Entertainment)
# - OSCARSOUND: Oscar for Best Sound (Frequency: one_off, Category: Entertainment)
# - KXOSCARSVIEWER: Oscars viewership (Frequency: custom, Category: Entertainment)
# - KXOSCARCOUNTBARBIE: Barbie Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARWINNERS: Oscar Winners (Frequency: annual, Category: Entertainment)
# - KXOSCARAS: Oscar for Best ANIMATED SHORT (Frequency: annual, Category: Entertainment)
# - OSCARCOSTUME: Oscar for Best Costume Design (Frequency: one_off, Category: Entertainment)
# - KXOSCARCOUNTWICKED: Wicked Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARSCORE: Oscar for Best Original Score (Frequency: annual, Category: Entertainment)
# - KXOSCARWIN: Most Oscar wins (Frequency: custom, Category: Entertainment)
# - KXOSCARCOUNTACU: A COmplete Unknown Oscar wins (Frequency: custom, Category: Entertainment)
# - OSCARSUPACTR: Oscar for Best Supporting Actress (Frequency: annual, Category: Entertainment)
# - KXOSCARNOMSUPACTR: Oscar nominations for Best Supporting Actress (Frequency: annual, Category: Entertainment)
# - KXOSCARVIS: Oscar for Best Visual Effects (Frequency: annual, Category: Entertainment)
# - KXOSCARNOMPIC: Oscar nominations for Best Picture (Frequency: annual, Category: Entertainment)
# - KXOSCARDOCU: Oscar for Best Documentary Feature (Frequency: annual, Category: Entertainment)

# %%
import requests

# Get series information for KXHIGHNY
url = "https://api.elections.kalshi.com/trade-api/v2/series/OSCARPIC"
response = requests.get(url)
print(f"Status Code: {response.status_code}")
series_data = response.json()
print(f"Total Series: {len(series_data['series'])}")
print(f"Series Data Keys: {series_data['series'].values()}")
print(f"Series Title: {series_data['series']['title']}")
print(f"Frequency: {series_data['series']['frequency']}")
print(f"Category: {series_data['series']['category']}")
print(series_data["series"]["ticker"])  # Outputs: OSCARPIC
# Out:
# Status Code: 200
# Total Series: 11
# Series Data Keys: dict_values([None, 'Entertainment', 'https://kalshi-public-docs.s3.amazonaws.com/contract_terms/OSCARS.pdf', 'https://kalshi-public-docs.s3.us-east-1.amazonaws.com/regulatory/product-certifications/OSCARS.pdf', 1, 'quadratic', 'annual', [{'name': 'Academy of Motion Picture Arts and Sciences', 'url': 'https://www.oscars.org/oscars'}], ['Awards', 'Movies', 'Oscars'], 'OSCARPIC', 'Oscar for Best Picture'])
# Series Title: Oscar for Best Picture
# Frequency: annual
# Category: Entertainment
# OSCARPIC

# %%
# Get all open markets for the KXHIGHNY series
markets_url = f"https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker=KXOSCARSUPACTR"
markets_response = requests.get(markets_url)
print(f"Status Code: {markets_response.status_code}")
markets_data = markets_response.json()
print(f"Total Markets in OSCARPIC series: {len(markets_data['markets'])}")

print(f"\nActive markets in OSCARPIC series:")
for market in markets_data['markets']:
    print(f"- {market['ticker']}: {market['title']}")
    print(f"  Event: {market['event_ticker']}")
    print(f"  Yes Price: {market['yes_ask']}¢ | Volume: {market['volume']}")
    print()

# Get details for a specific event if you have its ticker
if markets_data['markets']:
    # Let's get details for the first market's event
    event_ticker = markets_data['markets'][0]['event_ticker']
    event_url = f"https://api.elections.kalshi.com/trade-api/v2/events/{event_ticker}"
    event_response = requests.get(event_url)
    event_data = event_response.json()

    print(f"Event Details:")
    print(f"Title: {event_data['event']['title']}")
    print(f"Category: {event_data['event']['category']}")
# Out:
# Status Code: 200
# Total Markets in OSCARPIC series: 51
#
# Active markets in OSCARPIC series:
# - KXOSCARSUPACTR-26-ODE: Will Odessa A'zion win Best Supporting Actress at the Oscars?
#   Event: KXOSCARSUPACTR-26
#   Yes Price: 100¢ | Volume: 110585
#
# - KXOSCARSUPACTR-26-TIE: Will Tie win Best Supporting Actress at the Oscars?
#   Event: KXOSCARSUPACTR-26
#   Yes Price:
Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-24
#   Yes Price: 2¢ | Volume: 3677
#
# - OSCARSUPACTR-24-LG: Will Lily Gladstone win Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-24
#   Yes Price: 2¢ | Volume: 5197
#
# - OSCARSUPACTR-24-DJR: Will Da''Vine Joy Randolph win Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-24
#   Yes Price: 100¢ | Volume: 18661
#
# - OSCARSUPACTR-24-AF: Will America Ferrera win Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-24
#   Yes Price: 2¢ | Volume: 7427
#
# - OSCARSUPACTR-24-PC: Will Penélope Cruz win Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-24
#   Yes Price: 2¢ | Volume: 390
#
# - OSCARSUPACTR-24-EB: Will Emily Blunt win Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-24
#   Yes Price: 2¢ | Volume: 4804
#
# - OSCARSUPACTR-23-SH: Will Stephanie Hsu win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-23
#   Yes Price: 1¢ | Volume: 3672
#
# - OSCARSUPACTR-23-KC: Will Kerry Condon win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-23
#   Yes Price: 1¢ | Volume: 1109
#
# - OSCARSUPACTR-23-JLC: Will Jamie Lee Curtis win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-23
#   Yes Price: 100¢ | Volume: 2432
#
# - OSCARSUPACTR-23-HC: Will Hong Chau win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-23
#   Yes Price: 2¢ | Volume: 2022
#
# - OSCARSUPACTR-23-AB: Will Angela Bassett win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-23
#   Yes Price: 1¢ | Volume: 3448
#
# - OSCARSUPACTR-22-AD: Will Ariana DeBose win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-22
#   Yes Price: 100¢ | Volume: 16278
#
# - OSCARSUPACTR-22-KD: Will Kirsten Dunst win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-22
#   Yes Price: 1¢ | Volume: 8045
#
# - OSCARSUPACTR-22-AE: Will Aunjanue Ellis win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-22
#   Yes Price: 99¢ | Volume: 752
#
# - OSCARSUPACTR-22-JD: Will Judi Dench win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-22
#   Yes Price: 99¢ | Volume: 3784
#
# - OSCARSUPACTR-22-JB: Will Jessie Buckley win Best Supporting Actress at the Oscars?
#   Event: OSCARSUPACTR-22
#   Yes Price: 99¢ | Volume: 3271
#
# Event Details:
# Title: Oscar for Best Supporting Actress?
# Category: Entertainment

# %%
# Get orderbook for a specific market
# Replace with an actual market ticker from the markets list
if not markets_data['markets']:
    raise ValueError("No open markets found. Try removing status=open or choose another series.")

market_ticker = markets_data['markets'][0]['ticker']
print(f"\nFetching orderbook for market: {market_ticker}")
orderbook_url = f"https://api.elections.kalshi.com/trade-api/v2/markets/{market_ticker}/orderbook"

orderbook_response = requests.get(orderbook_url)
orderbook_data = orderbook_response.json()

print(f"\nOrderbook for {market_ticker}:")
print("YES BIDS:")
for bid in orderbook_data['orderbook']['yes'][:5]:  # Show top 5
    print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")

print("\nNO BIDS:")
for bid in orderbook_data['orderbook']['no'][:5]:  # Show top 5
    print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 # Get orderbook for a specific market
#       2 # Replace with an actual market ticker from the markets list
#       3 if not markets_data['markets']:
# ----> 4     raise ValueError("No open markets found. Try removing status=open or choose another series.")
#       6 market_ticker = markets_data['markets'][0]['ticker']
#       7 print(f"\nFetching orderbook for market: {market_ticker}")
#
# ValueError: No open markets found. Try removing status=open or choose another series.
