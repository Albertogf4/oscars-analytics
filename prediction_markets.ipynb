# %% [markdown]
# # Objects In Kalshi
#
# ## 1. Market (elemento mínimo -> extraes información básica de precio)
# A single binary market. This is a low level object ehich rarely will need to be exposed on its own to members. ç
#
# ## 2. Event (acontecimiento cultural que da lugar a una serie de mercados)
# An event is a collection of markets and the basic unit that members should interact with.
#
# ## 3. Series (catálogo de eventos relacionados entre sí)
# A series is a collection of related events.
# - Each event should look at similar data for determination, but translated over another, disjoint time period.
# - Series should never have logical outcom dependency between events
# - Events in a series should have the same ticker prefic

# %%
import requests

# Get series information for KXHIGHNY
url = "https://api.elections.kalshi.com/trade-api/v2/series/kxoscarpic-26"
response = requests.get(url)
series_data = response.json()

print(f"Series Title: {series_data['series']['title']}")
print(f"Frequency: {series_data['series']['frequency']}")
print(f"Category: {series_data['series']['category']}")
# Out:
# Status Code: 404
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 9
#       6 print(f"Status Code: {response.status_code}")
#       7 series_data = response.json()
# ----> 9 print(f"Series Title: {series_data['series']['title']}")
#      10 print(f"Frequency: {series_data['series']['frequency']}")
#      11 print(f"Category: {series_data['series']['category']}")
#
# KeyError: 'series'

# %%
# Get all open markets for the KXHIGHNY series
markets_url = f"https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker=KXHIGHNY&status=open"
markets_response = requests.get(markets_url)
markets_data = markets_response.json()

print(f"\nActive markets in KXHIGHNY series:")
for market in markets_data['markets']:
    print(market.keys())
    print(f"- {market['ticker']}: {market['title']}")
    print(f"  Event: {market['event_ticker']}")
    print(f"  Yes Price: {market['yes_ask']}¢ | Volume: {market['volume']}")
    print()

# Get details for a specific event if you have its ticker
if markets_data['markets']:
    # Let's get details for the first market's event
    event_ticker = markets_data['markets'][0]['event_ticker']
    event_url = f"https://api.elections.kalshi.com/trade-api/v2/events/{event_ticker}"
    event_response = requests.get(event_url)
    event_data = event_response.json()

    print(f"Event Details:")
    print(f"Title: {event_data['event']['title']}")
    print(f"Category: {event_data['event']['category']}")
# Out:
# Active markets in KXHIGHNY series:
# dict_keys(['can_close_early', 'close_time', 'created_time', 'early_close_condition', 'event_ticker', 'expected_expiration_time', 'expiration_time', 'expiration_value', 'floor_strike', 'last_price', 'last_price_dollars', 'latest_expiration_time', 'liquidity', 'liquidity_dollars', 'market_type', 'no_ask', 'no_ask_dollars', 'no_bid', 'no_bid_dollars', 'no_sub_title', 'notional_value', 'notional_value_dollars', 'open_interest', 'open_interest_fp', 'open_time', 'previous_price', 'previous_price_dollars', 'previous_yes_ask', 'previous_yes_ask_dollars', 'previous_yes_bid', 'previous_yes_bid_dollars', 'price_level_structure', 'price_ranges', 'response_price_units', 'result', 'rules_primary', 'rules_secondary', 'settlement_timer_seconds', 'status', 'strike_type', 'subtitle', 'tick_size', 'ticker', 'title', 'updated_time', 'volume', 'volume_24h', 'volume_24h_fp', 'volume_fp', 'yes_ask', 'yes_ask_dollars', 'yes_bid', 'yes_bid_dollars', 'yes_sub_title'])
# - KXHIGHNY-26FEB08-T24: Will the **high temp in NYC** be >24° on Feb 8, 2026?
#   Event: KXHIGHNY-26FEB08
#   Yes Price: 2¢ | Volume: 4565
#
# dict_keys(['can_close_early', 'cap_strike', 'close_time', 'created_time', 'early_close_condition', 'event_ticker', 'expected_expiration_time', 'expiration_time', 'expiration_value', 'last_price', 'last_price_dollars', 'latest_expiration_time', 'liquidity', 'liquidity_dollars', 'market_type', 'no_ask', 'no_ask_dollars', 'no_bid', 'no_bid_dollars', 'no_sub_title', 'notional_value', 'notional_value_dollars', 'open_interest', 'open_interest_fp', 'open_time', 'previous_price', 'previous_price_dollars', 'previous_yes_ask', 'previous_yes_ask_dollars', 'previous_yes_bid', 'previous_yes_bid_dollars', 'price_level_structure', 'price_ranges', 'response_price_units', 'result', 'rules_primary', 'rules_secondary', 'settlement_timer_seconds', 'status', 'strike_type', 'subtitle', 'tick_size', 'ticker', 'title', 'updated_time', 'volume', 'volume_24h', 'volume_24h_fp', 'volume_fp', 'yes_ask', 'yes_ask_dollars', 'yes_bid', 'yes_bid_dollars', 'yes_sub_title'])
# - KXHIGHNY-26FEB08-T17: Will the **high temp in NYC** be <17° on Feb 8, 2026?
#   Event: KXHIGHNY-26FEB08
#   Yes Price: 37¢ | Volume: 19638
#
# dict_keys(['can_close_early', 'cap_strike', 'close_time', 'created_time', 'early_close_condition', 'event_ticker', 'expected_expiration_time', 'expiration_time', 'expiration_value', 'floor_strike', 'last_price', 'last_price_dollars', 'latest_expiration_time', 'liquidity', 'liquidity_dollars', 'market_type', 'no_ask', 'no_ask_dollars', 'no_bid', 'no_bid_dollars', 'no_sub_title', 'notional_value', 'notional_value_dollars', 'open_interest', 'open_interest_fp', 'open_time', 'previous_price', 'previous_price_dollars', 'previous_yes_ask', 'previous_yes_ask_dollars', 'previous_yes_bid', 'previous_yes_bid_dollars', 'price_level_structure', 'price_ranges', 'response_price_units', 'result', 'rules_primary', 'rules_secondary', 'settlement_timer_seconds', 'status', 'strike_type', 'subtitle', 'tick_size', 'ticker', 'title', 'updated_time', 'volume', 'volume_24h', 'volume_24h_fp', 'volume_fp', 'yes_ask', 'yes_ask_dollars', 'yes_bid', 'yes_bid_dollars', 'yes_sub_title'])
# - KXHIGHNY-26FEB08-B23.5: Will the **high temp in NYC** be 23-24° on Feb 8, 2026?
#   Event: KXHIGHNY-26FEB08
#   Yes Price: 1¢ | Volume: 2767
#
# dict_keys(['can_close_early', 'cap_strike', 'close_time', 'created_time', 'early_close_condition', 'event_ticker', 'expected_expiration_time', 'expiration_time', 'expiration_value', 'floor_strike', 'last_price', 'last_price_dollars', 'latest_expiration_time', 'liquidity', 'liquidity_dollars', 'market_type', 'no_ask', 'no_ask_dollars', 'no_bid', 'no_bid_dollars', 'no_sub_title', 'notional_value', 'notional_value_dollars', 'open_interest', 'open_interest_fp', 'open_time', 'previous_price', 'previous_price_dollars', 'previous_yes_ask', 'previous_yes_ask_dollars', 'previous_yes_bid', 'previous_yes_bid_dollars', 'price_level_structure', 'price_ranges', 'response_price_units', 'result', 'rules_primary', 'rules_secondary', 'settlement_timer_seconds', 'status', 'strike_type', 'subtitle', 'tick_size', 'ticker', 'title', 'updated_time', 'volume', 'volume_24h', 'volume_24h_fp', 'volume_fp', 'yes_ask', 'yes_ask_dollars', 'yes_bid', 'yes_bid_dollars', 'yes_sub_title'])
# - KXHIGHNY-26FEB08-B21.5: Will the **high temp in NYC** be 21-22° on Feb 8, 2026?
#   Event: KXHIGHNY-26FEB08
#   Yes Price: 5¢ | Volume: 8394
#
# dict_keys(['can_close_early', 'cap_strike', 'close_time', 'created_time', 'early_close_condition', 'event_ticker', 'expected_expiration_time', 'expiration_time', 'expiration_value', 'floor_strike', 'last_price', 'last_price_dollars', 'latest_expiration_time', 'liquidity', 'liquidity_dollars', 'market_type', 'no_ask', 'no_ask_dollars', 'no_bid', 'no_bid_dollars', 'no_sub_title', 'notional_value', 'notional_value_dollars', 'open_interest', 'open_interest_fp', 'open_time', 'previous_price', 'previous_price_dollars', 'previous_yes_ask', 'previous_yes_ask_dollars', 'previous_yes_bid', 'previous_yes_bid_dollars', 'price_level_structure', 'price_ranges', 'response_price_units', 'result', 'rules_primary', 'rules_secondary', 'settlement_timer_seconds', 'status', 'strike_type', 'subtitle', 'tick_size', 'ticker', 'title', 'updated_time', 'volume', 'volume_24h', 'volume_24h_fp', 'volume_fp', 'yes_ask', 'yes_ask_dollars', 'yes_bid', 'yes_bid_dollars', 'yes_sub_title'])
# - KXHIGHNY-26FEB08-B19.5: Will the **high temp in NYC** be 19-20° on Feb 8, 2026?
#   Event: KXHIGHNY-26FEB08
#   Yes Price: 14¢ | Volume: 12728
#
# dict_keys(['can_close_early', 'cap_strike', 'close_time', 'created_time', 'early_close_condition', 'event_ticker', 'expected_expiration_time', 'expiration_time', 'expiration_value', 'floor_strike', 'last_price', 'last_price_dollars', 'latest_expiration_time', 'liquidity', 'liquidity_dollars', 'market_type', 'no_ask', 'no_ask_dollars', 'no_bid', 'no_bid_dollars', 'no_sub_title', 'notional_value', 'notional_value_dollars', 'open_interest', 'open_interest_fp', 'open_time', 'previous_price', 'previous_price_dollars', 'previous_yes_ask', 'previous_yes_ask_dollars', 'previous_yes_bid', 'previous_yes_bid_dollars', 'price_level_structure', 'price_ranges', 'response_price_units', 'result', 'rules_primary', 'rules_secondary', 'settlement_timer_seconds', 'status', 'strike_type', 'subtitle', 'tick_size', 'ticker', 'title', 'updated_time', 'volume', 'volume_24h', 'volume_24h_fp', 'volume_fp', 'yes_ask', 'yes_ask_dollars', 'yes_bid', 'yes_bid_dollars', 'yes_sub_title'])
# - KXHIGHNY-26FEB08-B17.5: Will the **high temp in NYC** be 17-18° on Feb 8, 2026?
#   Event: KXHIGHNY-26FEB08
#   Yes Price: 46¢ | Volume: 9644
#
# Event Details:
# Title: Highest temperature in NYC on Feb 8, 2026?
# Category: Climate and Weather

# %%
# Get orderbook for a specific market
# Replace with an actual market ticker from the markets list
if not markets_data['markets']:
    raise ValueError("No open markets found. Try removing status=open or choose another series.")

market_ticker = markets_data['markets'][0]['ticker']
print(f"\nFetching orderbook for market: {market_ticker}")
orderbook_url = f"https://api.elections.kalshi.com/trade-api/v2/markets/{market_ticker}/orderbook"

orderbook_response = requests.get(orderbook_url)
orderbook_data = orderbook_response.json()

print(f"\nOrderbook for {market_ticker}:")
print("YES BIDS:")
for bid in orderbook_data['orderbook']['yes'][:5]:  # Show top 5
    print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")

print("\nNO BIDS:")
for bid in orderbook_data['orderbook']['no'][:5]:  # Show top 5
    print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")
# Out:
# Fetching orderbook for market: KXHIGHNY-26FEB08-T24
#
# Orderbook for KXHIGHNY-26FEB08-T24:
# YES BIDS:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 15
#      13 print(f"\nOrderbook for {market_ticker}:")
#      14 print("YES BIDS:")
# ---> 15 for bid in orderbook_data['orderbook']['yes'][:5]:  # Show top 5
#      16     print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")
#      18 print("\nNO BIDS:")
#
# TypeError: 'NoneType' object is not subscriptable
